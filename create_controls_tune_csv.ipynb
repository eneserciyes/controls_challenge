# %%
import pandas as pd

# %%
traj = pd.read_csv("data/00000.csv")

# %%
traj["targetLateralAcceleration"][100:] = 0.1

# %%
traj[99:]
# Out:
#         t       vEgo      aEgo      roll  targetLateralAcceleration  \
# 99    9.9  33.633702 -0.042949 -0.011553                  -0.015998
# 100  10.0  33.639615  0.043365 -0.011601                   0.100000
# 101  10.1  33.624151 -0.081701 -0.011973                   0.100000
# 102  10.2  33.640215  0.028456 -0.012345                   0.100000
# 103  10.3  33.641140  0.007719 -0.012240                   0.100000
# ..    ...        ...       ...       ...                        ...
# 595  59.5  33.608443  0.014698 -0.015182                   0.100000
# 596  59.6  33.609664  0.040146 -0.015666                   0.100000
# 597  59.7  33.593987 -0.063141 -0.016151                   0.100000
# 598  59.8  33.594516 -0.035502 -0.016635                   0.100000
# 599  59.9  33.584257 -0.095617 -0.017119                   0.100000
#
#      steerCommand
# 99      -0.036894
# 100           NaN
# 101           NaN
# 102           NaN
# 103           NaN
# ..            ...
# ...

# %%
traj.to_csv("pid_tune.csv",index=False)
